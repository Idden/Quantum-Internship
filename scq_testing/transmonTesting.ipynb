# %%
import scqubits as scq
import numpy as np
import matplotlib.pyplot as plt

# %%
tmon = scq.Transmon.create()

transmon1 = scq.Transmon(
    EJ=30.0,
    EC=1.2,
    ng=0.3,
    ncut=31
)

transmon2 = scq.Transmon(
    EJ=30.0,
    EC=1.2,
    ng=1.5,
    ncut=31
)

eval, evecs = tmon.eigensys(evals_count=3)
# Out:
# ...
# For use with jupyter lab, additionally execute `jupyter labextension install jupyter-vuetify`.
#
#  c:\Users\idden\AppData\Local\Programs\Python\Python313\Lib\site-packages\scqubits\utils\misc.py: 143

# %%
ng_list = np.linspace(-2, 2, 220)
transmon1.plot_matelem_vs_paramvals('n_operator', 'ng', ng_list, select_elems=4)
# Out:
# Spectral data:   0%|          | 0/220 [00:00<?, ?it/s]
# (<Figure size 640x480 with 1 Axes>,
#  <Axes: xlabel='$n_g$', ylabel='matrix element'>)

# %%
transmon1.plot_matrixelements('n_operator', evals_count=10)
transmon1.plot_matrixelements('cos_phi_operator', evals_count=10, show3d=False, show_numbers=True)
# Out:
# (<Figure size 640x480 with 2 Axes>, <Axes: >)

# %%
transmon1.plot_n_wavefunction(esys=None, which=0, mode='real')
transmon2.plot_n_wavefunction(esys=None, which=0, mode='real')
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <Axes: xlabel='n', ylabel='Re $\\psi_j(n)$'>)

# %%
tmon.plot_phi_wavefunction(esys=None, which=[0,1,2,3,4], mode='real');

# %%
ng_list = np.linspace(-2, 2, 220)
transmon1.plot_evals_vs_paramvals('ng', ng_list, evals_count=5, subtract_ground=True)
# Out:
# Spectral data:   0%|          | 0/220 [00:00<?, ?it/s]
# (<Figure size 640x480 with 1 Axes>,
#  <Axes: xlabel='$n_g$', ylabel='energy [GHz]'>)

# %%
EJvals = np.linspace(0.1, 35, 100)
tmon.plot_dispersion_vs_paramvals('ng', 'EJ', EJvals, ref_param='EC', levels=(0,1,2))
tmon.plot_dispersion_vs_paramvals('ng', 'EJ', EJvals, ref_param='EC', transitions=(((0,1), (0,2))))
# Out:
# ...
# Spectral data:   0%|          | 0/100 [00:00<?, ?it/s]
# (<Figure size 640x480 with 1 Axes>,
#  <Axes: xlabel='EJ/EC', ylabel='energy dispersion [GHz]'>)
