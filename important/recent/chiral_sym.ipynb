# %%
import numpy as np
import qutip as qt
import matplotlib.pyplot as plt
from quantumScarFunctions import *
from quantumScarsPlotting import *

# %%
wd = 0.6366896896896898
t_max = 200
tlist = np.linspace(0, t_max, 400)
N = 6
dis = [0.1, 0, 0]

# %%
H0_clean, _, _, psi0, basisList = get_scar_ham(N)
H1, driveWeights = get_scar_H1(N, basisList)
H0, eigenvalues, eigenstates = get_dis_scar_ham(H0_clean, N, basisList, 
                                                ham_disorder=dis)

plotEigEnergies(H0, N, chiral_test=True)
plotAmpEigenstatesZ2Log(H0, psi0, N)
# Out:
# Chiral Symmetry Test:  -1.7763568394002505e-15
