# %%
import numpy as np
import matplotlib.pyplot as plt

pathx = "npy_files/Rtau_N18_dz0.0_dy0.0_dx0.3_reals426_tmax200_PARTIAL_AVG.npz"
pathy = "npy_files/Rtau_N18_dz0.0_dy0.3_dx0.0_reals453_tmax200_PARTIAL_AVG.npz"
pathz = "npy_files/Rtau_N18_dz0.3_dy0.0_dx0.0_reals495_tmax200_PARTIAL_AVG.npz"

datax = np.load(pathx)
datay = np.load(pathy)
dataz = np.load(pathz)

# %%
tlist = datax["tlist"]
xavged_scar = datax["avged_scar"]

plt.plot(tlist, xavged_scar)
plt.ylim(0,1)
plt.show()

tlist = datay["tlist"]
yavged_scar = datay["avged_scar"]

plt.plot(tlist, yavged_scar)
plt.ylim(0,1)
plt.show()

tlist = dataz["tlist"]
zavged_scar = dataz["avged_scar"]
plt.plot(tlist, zavged_scar)
plt.ylim(0,1)
plt.show()
