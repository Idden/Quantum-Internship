# %%
import numpy as np
import matplotlib.pyplot as plt

path = "npy_files/Rtau_N8_dz0.0_dy0.0_dx0.3_reals500_tmax200.npz"

data = np.load(path)

print(data.files)          # shows what arrays are inside

tlist = data["tlist"]
avged_scar = data["avged_scar"]
scar_results = data["scar_results"]

print(tlist.shape)
plt.plot(tlist, avged_scar)
plt.ylim(0,1)
plt.show()
# Out:
# ['tlist', 'scar_results', 'avged_scar', 'seeds_loaded', 'N', 'wd', 'dz', 'dy', 'dx', 'reals', 't_max']
# (400,)
