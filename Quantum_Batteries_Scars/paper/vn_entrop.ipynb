# %%
import numpy as np
import qutip as qt
import matplotlib.pyplot as plt
from GitHub_QM.Quantum_Batteries_Scars.paper.helper.quantumScarFunctions import *
from GitHub_QM.Quantum_Batteries_Scars.paper.helper.quantumScarsPlotting import *

# %%
N = 14
wd = 0.6366896896896898
tlist = np.linspace(0, 200, 400)

vn_plot = plot_scar_vn_entrop(N, wd, tlist=tlist, disorder=[0, 0, 0], reals=200, save_fig=True)

# %%
N = 4
tlist = np.linspace(0, 100000, 100000)
vn_plot = plot_scar_vn_entrop(N, wd, tlist=tlist, disorder=[0, 0, 0], reals=1)
