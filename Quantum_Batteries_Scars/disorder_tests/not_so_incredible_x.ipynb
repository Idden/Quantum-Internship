# %%
import numpy as np
import qutip as qt
import matplotlib.pyplot as plt
from quantumScarFunctions import *
from quantumScarsPlotting import *

# %%
N = 6
wd = 0.6365091993031
wm = 1.0
freq_dis = 0.00
indv_qubit = False
t_max = 100
tlist = np.linspace(0, t_max, t_max * 2)
reals = 200
rand = True

dz = 0.0
dy = 0.0
dx = 6.0

H0, H1, eigenvalues, eigenstates, psi0, basisList = get_scar_ham(N, ham_disorder=[dz, dy, dx], random_seed=rand, indv_qubit=indv_qubit)
plotEigEnergies(H0, N)

H0, H1, eigenvalues, eigenstates, psi0, basisList = get_scar_ham(N, ham_disorder=[0, 0, 0], random_seed=rand, indv_qubit=indv_qubit)
plotEigEnergies(H0, N)
