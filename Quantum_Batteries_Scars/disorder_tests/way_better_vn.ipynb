# %%
import numpy as np
import qutip as qt
import matplotlib.pyplot as plt
from quantumScarFunctions import *
from quantumScarsPlotting import *

# %%
N = 14
wd = 0.6365091993031289
tlist = np.linspace(0, 200, 400)

# about 4x speed up 2.4s and 9.8s
vn_plot = plot_scar_vn_entrop(N, wd, tlist=tlist, disorder=[0, 0, 0], reals=1)

# %%
N = 4
tlist = np.linspace(0, 10000, 10000)
vn_plot = plot_scar_vn_entrop(N, wd, tlist=tlist, disorder=[0, 0, 0], reals=1)
